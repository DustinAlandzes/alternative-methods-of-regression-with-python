# %% [markdown]
# <a href="https://colab.research.google.com/github/f00-/alternative-methods-of-regression-with-python/blob/master/loading_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Table 1.1
# ## Turnip Green Data
#
# *Source:* Drape and Smith (1981, p. 406)

# %%
turnips_df = pd.read_csv("https://github.com/f00-/alternative-methods-of-regression-with-python/raw/master/turnips.csv")
turnips_df.head(27)
# Out:
#     id  vitamin b_2  sunlight  soil moisture  air temperature
# 0    1        110.4       176            7.0               78
# 1    2        102.8       155            7.0               89
# 2    3        101.0       273            7.0               89
# 3    4        108.4       273            7.0               72
# 4    5        100.7       256            7.0               84
# 5    6        100.3       280            7.0               87
# 6    7        102.0       280            7.0               74
# 7    8         93.7       184            7.0               87
# 8    9         98.9       216            7.0               88
# 9   10         96.6       198            2.0               76
# 10  11         99.4        59            2.0               65
# 11  12         96.2        80            2.0               67
# 12  13         99.0        80            2.0               62
# 13  14         88.4       105            2.0               70
# ...

# %% [markdown]
# ## Table 1.3
# ## Birth Rate Data
#
# *Source: * World Resources Institute (1986)

# %%
birthrate_df = pd.read_csv("https://github.com/f00-/alternative-methods-of-regression-with-python/raw/master/birthrate.csv")
birthrate_df.head(13)
# Out:
#                country  birth rate  urban percentage
# 0               canada        16.2              55.0
# 1           costa rica        30.5              27.3
# 2                 cuba        16.9              33.3
# 3   dominican republic        33.1              37.1
# 4          el salvador        40.2              11.5
# 5            guatemala        38.4              14.2
# 6                haiti        41.3              13.9
# 7             honduras        43.9              19.0
# 8              jamaica        28.3              33.1
# 9               mexico        33.9              43.2
# 10           nicaragua        44.2              28.5
# 11              panama        28.0              37.7
# 12     trinidad/tobago        24.6               6.8

# %%
# todo: regression lines (LS, LS ignoring T/T, LAD)
# style, ticks on y axis
plt.style.use('ggplot')
birthrate_df.plot(x="urban percentage", y="birth rate", kind="scatter", ylim=0)

# %% [markdown]
# ## Table 1.4
# ## Galton's Sweet Pea Data
#
# *Source: * Galton (1886)

# %%
peas_df = pd.read_csv("https://github.com/f00-/alternative-methods-of-regression-with-python/raw/master/peas.csv")
peas_df.head(6)
# Out:
#    diameter of parent  mean diameter of offspring
# 0                  21                        17.5
# 1                  20                        17.3
# 2                  19                        16.0
# 3                  18                        16.3
# 4                  17                        15.6
# 5                  16                        16.0

# %%
# todo ticks style, figure 1.3
peas_df.plot(x="diameter of parent", y="mean diameter of offspring", kind="scatter")

# %% [markdown]
# ## Table 3.1
# Acid Content Data
#
# *Source: * Daniel and Wood (1980, p. 46)

# %%
acid_df = pd.read_csv("https://raw.githubusercontent.com/f00-/alternative-methods-of-regression-with-python/master/acidcontent.csv")
acid_df.head(20)
# Out:
#     id  expensive measurement  cheap measurement
# 0    1                     76                123
# 1    2                     70                109
# 2    3                     55                 62
# 3    4                     71                104
# 4    5                     55                 57
# 5    6                     48                 37
# 6    7                     50                 44
# 7    8                     66                100
# 8    9                     41                 16
# 9   10                     43                 28
# 10  11                     82                138
# 11  12                     68                105
# 12  13                     88                159
# 13  14                     58                 75
# 14  15                     64                 88
# 15  16                     88                164
# 16  17                     89                169
# 17  18                     88                167
# ...

# %% [markdown]
# ## Table 3.2
# ## Test Case for Linear Regression

# %% [markdown]
# ## Table 4.3
# ## Fire Data
#
# *Source: * Andrews and Herzberg (1985, p. 409)
# *Table 67.1 Information on Predominantly Residential
#             Areas in Chicago Based on ZIP Codes *
#  https://www2.stat.duke.edu/courses/Spring01/sta114/data/andrews.html

# %%
fire_df = pd.read_csv("https://raw.githubusercontent.com/f00-/alternative-methods-of-regression-with-python/master/fire.csv")
fire_df.head(30)
# Out:
#     Unnamed: 0  zipcode     x  FIRE  THEFT   AGE     y    z  INCOME
# 0            0    60626  10.0   6.2     29  60.4   5.3  0.0   11744
# 1            1    60640  22.2   9.5     44  76.5   3.1  0.1    9323
# 2            2    60613  19.6  10.5     36  73.5   4.8  1.2    9948
# 3            3    60657  17.3   7.7     37  66.9   5.7  0.5   10656
# 4            4    60614  24.5   8.6     53  81.4   5.9  0.7    9730
# 5            5    60610  54.0  34.1     68  52.6   4.0  0.3    8231
# 6            6    60611   4.9  11.0     75  42.6   7.9  0.0   21480
# 7            7    60625   7.1   6.9     18  78.5   6.9  0.0   11104
# 8            8    60618   5.3   7.3     31  90.1   7.6  0.4   10694
# 9            9    60647  21.5  15.1     25  89.8   3.1  1.1    9631
# 10          10    60622  43.1  29.1     34  82.7   1.3  1.9    7995
# 11          11    60631   1.1   2.2     14  40.2  14.3  0.0   13722
# 12          12    60646   1.0   5.7     11  27.9  12.1  0.0   16250
# ...

# %% [markdown]
# ## Table 5.1
# ## Shelf Life Data
#
# *Source: * Devore and Peck (1986, pp. 471-472)

# %%
shelf_df = pd.read_csv("https://raw.githubusercontent.com/f00-/alternative-methods-of-regression-with-python/master/shelf-life.csv")
shelf_df.head(20)
# Out:
#     id  moisture content  days on shelf
# 0    1               2.8              0
# 1    2               3.0              3
# 2    3               3.1              6
# 3    4               3.2              8
# 4    5               3.4             10
# 5    6               3.4             13
# 6    7               3.5             16
# 7    8               3.1             20
# 8    9               3.8             24
# 9   10               4.0             27
# 10  11               4.1             30
# 11  12               4.3             34
# 12  13               4.4             37
# 13  14               4.9             41

# %% [markdown]
# ## Table 5.3
# ## Aerobic Fitness Data
# *Source: * SAS Institute Inc. (1990, p. 1443)
#
# https://support.sas.com/documentation/cdl/en/statug/63962/HTML/default/viewer.htm#statug_reg_sect053.htm
#
# ```
# *-------------------Data on Physical Fitness-------------------*
# | These measurements were made on men involved in a physical   |
# | fitness course at N.C.State Univ. The variables are Age      |
# | (years), Weight (kg), Oxygen intake rate (ml per kg body     |
# | weight per minute), time to run 1.5 miles (minutes), heart   |
# | rate while resting, heart rate while running (same time      |
# | Oxygen rate measured), and maximum heart rate recorded while |
# | running.                                                     |
# | ***Certain values of MaxPulse were changed for this analysis.|
# *--------------------------------------------------------------*;
# ```

# %%
aerobic_df = pd.read_csv("https://raw.githubusercontent.com/f00-/alternative-methods-of-regression-with-python/master/aerobic.csv", delim_whitespace=True)
aerobic_df.head(31)
# Out:
#     Age  Weight  Oxygen  RunTime  RestPulse  RunPulse  MaxPulse
# 0    44   89.47  44.609    11.37         62       178       182
# 1    40   75.07  45.313    10.07         62       185       185
# 2    44   85.84  54.297     8.65         45       156       168
# 3    42   68.15  59.571     8.17         40       166       172
# 4    38   89.02  49.874     9.22         55       178       180
# 5    47   77.45  44.811    11.63         58       176       176
# 6    40   75.98  45.681    11.95         70       176       180
# 7    43   81.19  49.091    10.85         64       162       170
# 8    44   81.42  39.442    13.08         63       174       176
# 9    38   81.87  60.055     8.63         48       170       186
# 10   44   73.03  50.541    10.13         45       168       168
# 11   45   87.66  37.388    14.03         56       186       192
# 12   45   66.45  44.754    11.12         51       176       176
# 13   47   79.15  47.273    10.60         47       162       164
# ...

# %%
response = requests.get("http://users.stat.ufl.edu/~presnell/Courses/sta6208-1996sp/Files/houses.txt")
print(response.text)
# Out:
# Data from Jane Myers, Coldwell-Banker, on prices for houses sold in
# Northwest Gainesville in December 1995.
#
# Price = selling price of house (thousands of dollars)
# Area  = area (thousands of square feet)
# Bdrm  = no. of bedrooms
# Bath  = no. of bathrooms
# New   = whether new (1 = yes)

# %%
response = requests.get("http://users.stat.ufl.edu/~presnell/Courses/sta6208-1996sp/Files/houses.dat")

# Throw an error for bad status codes
response.raise_for_status()

with open('houses.dat', 'wb') as handle:
    for block in response.iter_content(1024):
        handle.write(block)
        
houses_df = pd.read_fwf('houses.dat')
houses_df
# Out:
#     Price  Area  Bdrm  Bath  New
# 0    48.5  1.10     3     1    0
# 1    55.0  1.01     3     2    0
# 2    68.0  1.45     3     2    0
# 3   137.0  2.40     3     3    0
# 4   309.4  3.30     4     3    1
# 5    17.5  0.40     1     1    0
# 6    19.6  1.28     3     1    0
# 7    24.5  0.74     3     1    0
# 8    34.8  0.78     2     1    0
# 9    32.0  0.97     3     1    0
# 10   28.0  0.84     3     1    0
# 11   49.9  1.08     2     2    0
# 12   59.9  0.99     2     1    0
# 13   61.5  1.01     3     2    0
# 14   60.0  1.34     3     2    0
# 15   65.9  1.22     3     1    0
# 16   67.9  1.28     3     2    0
# 17   68.9  1.29     3     2    0
# 18   69.9  1.52     3     2    0
# 19   70.5  1.25     3     2    0
# 20   72.9  1.28     3     2    0
# 21   72.5  1.28     3     1    0
# 22   72.0  1.36     3     2    0
# 23   71.0  1.20     3     2    0
# 24   76.0  1.46     3     2    0
# 25   72.9  1.56     4     2    0
# 26   73.0  1.22     3     2    0
# ...

# %% [markdown]
# ## Table 8.1
# ## Height data
#
# *Source: * Weisberg (1985, p. 57)
#
# https://github.com/cran/alr3/blob/master/data/BGSgirls.rda

# %% [markdown]
# ## Table 8.2
# ## Cement Data
#
# *Source: * Hald (1952, p. 647)
# https://github.com/cran/RXshrink/blob/master/data/haldport.rda

# %%
haldport_df = pd.read_csv("https://raw.githubusercontent.com/f00-/alternative-methods-of-regression-with-python/master/haldport.csv")
haldport_df.head(14)
# Out:
#     Unnamed: 0  p3ca  p3cs  p4caf  p2cs   heat
# 0            1     7    26      6    60   78.5
# 1            2     1    29     15    52   74.3
# 2            3    11    56      8    20  104.3
# 3            4    11    31      8    47   87.6
# 4            5     7    52      6    33   95.9
# 5            6    11    55      9    22  109.2
# 6            7     3    71     17     6  102.7
# 7            8     1    31     22    44   72.5
# 8            9     2    54     18    22   93.1
# 9           10    21    47      4    26  115.9
# 10          11     1    40     23    34   83.8
# 11          12    11    66      9    12  113.3
# 12          13    10    68      8    12  109.4

# %% [markdown]
# ## Table 9.2
# ## Stack Loss Data
#
# *Source: * Brownlee (1965, p. 454)

# %%
stackloss_df = pd.read_csv("https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/stackloss.csv")
stackloss_df.head(20)
# Out:
#     Unnamed: 0  Air.Flow  Water.Temp  Acid.Conc.  stack.loss
# 0            1        80          27          89          42
# 1            2        80          27          88          37
# 2            3        75          25          90          37
# 3            4        62          24          87          28
# 4            5        62          22          87          18
# 5            6        62          23          87          18
# 6            7        62          24          93          19
# 7            8        62          24          93          20
# 8            9        58          23          87          15
# 9           10        58          18          80          14
# 10          11        58          18          89          14
# 11          12        58          17          88          13
# 12          13        58          18          82          11
# 13          14        58          19          93          12
# ...

# %%
forearm_df = pd.read_csv("https://github.com/f00-/alternative-methods-of-regression-with-python/raw/master/forearm%20length.csv")
forearm_df.head(20)
# Out:
#     height  forearm length
# 0    165.8            28.1
# 1    169.8            29.1
# 2    170.7            29.5
# 3    170.9            28.2
# 4    157.5            27.3
# 5    165.9            29.0
# 6    158.7            27.8
# 7    166.0            26.9
# 8    158.7            27.1
# 9    161.5            27.8
# 10   167.3            27.3
# 11   167.4            30.9
# 12   159.2            27.3
# 13   170.0            30.9
# 14   166.3            28.8
# 15   169.0            28.8
# 16   156.2            25.6
# 17   159.6            25.4
# 18   155.0            26.6
# 19   161.1            26.6
